# %%
import cv2 
from matplotlib import pyplot as plt

# %%
OBRAZY = '/home/adam/studia/piro/proj2/PIRO_project2/data/ocr1'
img = cv2.imread(OBRAZY+'/img_1.jpg',0)

# %%
edges = cv2.Canny(img,220,350)
# edges = cornerEigenValsAndVecs(img)

plt.gcf().set_size_inches(50, 30)
plt.subplot(121),plt.imshow(img,cmap = 'gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(edges,cmap = 'gray')
plt.title('Edge Image'), plt.xticks([]), plt.yticks([])
plt.savefig('file.pdf')
plt.show()

# %%
source_path = Path('../data/ocr1/')
save_path = Path('../data/partial_results')
save_path.mkdir(parents=True, exist_ok=True)

# images_paths = source_path.glob("*.jpg")

for i in range(1,29):
    img = cv2.imread(source_path +'/img_{0}.jpg'.format(i),0)
    edges = cv2.Canny(img,220,350)
    # edges = cornerEigenValsAndVecs(img)

    plt.gcf().set_size_inches(50, 30)
    plt.subplot(120+i),plt.imshow(edges,cmap = 'gray')
    plt.title('Edge Image{0}'.format(i)), plt.xticks([]), plt.yticks([])
plt.savefig('file.pdf')
plt.show()
# Out:
#   File "<ipython-input-70-663a945773bb>", line 7
#     for i in range(1,29):
#                          ^
# SyntaxError: unexpected EOF while parsing

# %%
img0 = cv2.imread(OBRAZY+'/img_16.jpg')
gray = cv2.cvtColor(img0, cv2.COLOR_BGR2GRAY)
img2 = cv2.GaussianBlur(img,(3,3),0)

plt.gcf().set_size_inches(50, 30)

# convolute with proper kernels
laplacian = cv2.Laplacian(img2,cv2.CV_64F)
sobelx = cv2.Sobel(img2,cv2.CV_64F,1,0,ksize=5)  # x
sobely = cv2.Sobel(img2,cv2.CV_64F,0,1,ksize=5)  # y

plt.subplot(2,2,1),plt.imshow(img2,cmap = 'gray')
plt.title('Original'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,2),plt.imshow(laplacian,cmap = 'gray')
plt.title('Laplacian'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,3),plt.imshow(sobelx,cmap = 'gray')
plt.title('Sobel X'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,4),plt.imshow(sobely,cmap = 'gray')
plt.title('Sobel Y'), plt.xticks([]), plt.yticks([])

plt.show()
